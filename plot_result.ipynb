# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

plt.rc('font', size = 14)
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
MSE_record = torch.load('MSE_record.pt') ##(dt, sigma, exp)
MSE_det_record = torch.load('MSE_det_record.pt')
dt_list = torch.load('dt_list.pt')
sigma_list = [0.0, 0.01, 0.02]
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/3397387448.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
dt_list
# Out:
# array([0.002, 0.004, 0.01 , 0.02 , 0.1  ])

# %%
plt.figure()
plt.plot(dt_list, MSE_record[:, 0, :].mean(axis=-1), label = r'$\sigma = 0.0$')
plt.plot(dt_list, MSE_record[:, 1, :].mean(axis=-1), label = r'$\sigma = 0.01$')
plt.plot(dt_list, MSE_record[:, 2, :].mean(axis=-1), label = r'$\sigma = 0.02$')
plt.fill_between(dt_list, MSE_record[:, 0, :].mean(axis=-1) - MSE_record[:, 0, :].std(axis=-1), MSE_record[:, 0, :].mean(axis=-1) + MSE_record[:, 0, :].std(axis=-1), alpha = 0.2)
plt.fill_between(dt_list, MSE_record[:, 1, :].mean(axis=-1) - MSE_record[:, 1, :].std(axis=-1), MSE_record[:, 1, :].mean(axis=-1) + MSE_record[:, 1, :].std(axis=-1), alpha = 0.2)
plt.fill_between(dt_list, MSE_record[:, 2, :].mean(axis=-1) - MSE_record[:, 2, :].std(axis=-1), MSE_record[:, 2, :].mean(axis=-1) + MSE_record[:, 2, :].std(axis=-1), alpha = 0.2)
plt.plot(dt_list, MSE_det_record[:,0,:].mean(axis=-1), label = 'Deterministic')
plt.fill_between(dt_list, MSE_det_record[:,0,:].mean(axis=-1) - MSE_det_record[:,0,:].std(axis=-1), MSE_det_record[:,0,:].mean(axis=-1) + MSE_det_record[:,0,:].std(axis=-1), alpha = 0.2)
plt.xlabel('dt')
plt.ylabel('MSE')
plt.legend()
plt.xscale('log')
# plt.yscale('log')
# plt.xticks(dt_list)
plt.show()

# %%
MSE_record_sigma003 = torch.load('MSE_record_sigma0.03.pt') ##(dt, sigma, exp)
MSE_det_record_sigma003 = torch.load('MSE_det_record_sigma0.03.pt')
dt_list = torch.load('dt_list.pt')
sigma_list = [0.0, 0.01, 0.02]
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/968085553.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
# plt.plot(dt_list, MSE_record[:, 0, :].mean(axis=-1), label = r'$\sigma = 0.0$')
# plt.plot(dt_list, MSE_record[:, 1, :].mean(axis=-1), label = r'$\sigma = 0.03$')
# # plt.plot(dt_list, MSE_record[:, 2, :].mean(axis=-1), label = r'$\sigma = 0.02$')
plt.plot(dt_list, MSE_record_sigma003[:, 0, :].mean(axis=-1), label = r'$\sigma = 0.0$')
plt.plot(dt_list, MSE_record_sigma003[:, 1, :].mean(axis=-1), label = r'$\sigma = 0.03$')
# plt.fill_between(dt_list, MSE_record[:, 0, :].mean(axis=-1) - MSE_record[:, 0, :].std(axis=-1), MSE_record[:, 0, :].mean(axis=-1) + MSE_record[:, 0, :].std(axis=-1), alpha = 0.2)
# plt.fill_between(dt_list, MSE_record[:, 1, :].mean(axis=-1) - MSE_record[:, 1, :].std(axis=-1), MSE_record[:, 1, :].mean(axis=-1) + MSE_record[:, 1, :].std(axis=-1), alpha = 0.2)
# plt.fill_between(dt_list, MSE_record[:, 2, :].mean(axis=-1) - MSE_record[:, 2, :].std(axis=-1), MSE_record[:, 2, :].mean(axis=-1) + MSE_record[:, 2, :].std(axis=-1), alpha = 0.2)
plt.fill_between(dt_list, MSE_record_sigma003[:, 0, :].mean(axis=-1) - MSE_record_sigma003[:, 0, :].std(axis=-1), MSE_record_sigma003[:, 0, :].mean(axis=-1) + MSE_record_sigma003[:, 0, :].std(axis=-1), alpha = 0.2)
plt.fill_between(dt_list, MSE_record_sigma003[:, 1, :].mean(axis=-1) - MSE_record_sigma003[:, 1, :].std(axis=-1), MSE_record_sigma003[:, 1, :].mean(axis=-1) + MSE_record_sigma003[:, 1, :].std(axis=-1), alpha = 0.2)
plt.plot(dt_list, MSE_det_record_sigma003[:,0,:].mean(axis=-1), label = 'Deterministic')
plt.fill_between(dt_list, MSE_det_record_sigma003[:,0,:].mean(axis=-1) - MSE_det_record_sigma003[:,0,:].std(axis=-1), MSE_det_record_sigma003[:,0,:].mean(axis=-1) + MSE_det_record_sigma003[:,0,:].std(axis=-1), alpha = 0.2)
plt.xlabel('dt')
plt.ylabel('MSE')
plt.legend(loc='upper right')
plt.xscale('log')
# plt.yscale('log')
# plt.xticks(dt_list)
plt.show()

# %%
MSE_record = torch.load('MSE_dt_N2000_epsilon0.3.pt') ##(dt, 4method, exp)
dt_list = torch.load('dt_list.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/2403409198.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
MSE_k = torch.load('MSE_dt_N4000_epsilon0.3_only_k.pt') ##(dt, 4method, exp)
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/1155209887.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
det_dt_list = [0.002, 0.004, 0.01 , 0.02 , 0.1  ]

# %%
## Training 8000 times sigma=0
plt.figure()
plt.plot(dt_list, MSE_record[:, 0, :].mean(axis=-1), label = 'NN without control',color='C0')
plt.plot(dt_list, MSE_record[:, 1, :].mean(axis=-1), label = 'NN with control',color='C1')
plt.plot(dt_list, MSE_record[:, 2, :].mean(axis=-1), label = 'Exact solution',color='C2')
# plt.plot(dt_list[1:], MSE_record[1:, 3, :].mean(axis=-1), label = 'Approximate k',color='C3')
plt.plot(dt_list, MSE_k[:, 3, :].mean(axis=-1), label = 'Approximate k',color='C3')
plt.fill_between(dt_list, MSE_record[:, 0, :].min(axis=-1), MSE_record[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(dt_list, MSE_record[:, 1, :].min(axis=-1), MSE_record[:, 1, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(dt_list, MSE_record[:, 2, :].min(axis=-1), MSE_record[:, 2, :].max(axis=-1) , alpha = 0.2,color='C2')
plt.fill_between(dt_list, MSE_k[:, 3, :].min(axis=-1), MSE_k[:, 3, :].max(axis=-1) , alpha = 0.2,color='C3')
# plt.fill_between(dt_list[1:], MSE_record[1:, 3, :].mean(axis=-1) - MSE_record[1:, 3, :].std(axis=-1), MSE_record[1:, 3, :].mean(axis=-1) + MSE_record[1:, 3, :].std(axis=-1), alpha = 0.2,color='C3')
# plt.fill_between(dt_list, MSE_record[:, 3, :].mean(axis=-1) - MSE_record[:, 3, :].std(axis=-1), MSE_record[:, 3, :].mean(axis=-1) + MSE_record[:, 3, :].std(axis=-1), alpha = 0.2,color='C3')
plt.plot(det_dt_list, MSE_det_record[:,0,:].mean(axis=-1), label = 'Deterministic', color='C4')
plt.fill_between(det_dt_list, MSE_det_record[:,0,:].mean(axis=-1) - MSE_det_record[:,0,:].std(axis=-1), MSE_det_record[:,0,:].mean(axis=-1) + MSE_det_record[:,0,:].std(axis=-1), alpha = 0.2, color='C4')
plt.xlabel('dt')
plt.ylabel('MSE')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
MSE_record = torch.load('MSE_dt_N2000_epsilon0.3_new.pt') ##(dt, 4method, exp)
dt_list = torch.load('dt_list.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/2265386469.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
## Training 12000 times sigma=0
plt.figure()
plt.plot(dt_list, MSE_record[:, 0, :].mean(axis=-1), label = 'NN without control',color='C0')
plt.plot(dt_list, MSE_record[:, 1, :].mean(axis=-1), label = 'NN with control',color='C1')
plt.plot(dt_list, MSE_record[:, 2, :].mean(axis=-1), label = 'Exact solution',color='C2')
plt.plot(dt_list, MSE_record[:, 3, :].mean(axis=-1), label = 'Approximate k',color='C3')
plt.plot(dt_list, MSE_record[:, 4, :].mean(axis=-1), label = 'Open loop',color='C4')
plt.fill_between(dt_list, MSE_record[:, 0, :].min(axis=-1), MSE_record[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(dt_list, MSE_record[:, 1, :].min(axis=-1), MSE_record[:, 1, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(dt_list, MSE_record[:, 2, :].min(axis=-1), MSE_record[:, 2, :].max(axis=-1) , alpha = 0.2,color='C2')
plt.fill_between(dt_list, MSE_record[:, 3, :].min(axis=-1), MSE_record[:, 3, :].max(axis=-1) , alpha = 0.2,color='C3')
plt.fill_between(dt_list, MSE_record[:, 4, :].min(axis=-1), MSE_record[:, 4, :].max(axis=-1) , alpha = 0.2,color='C4')
plt.xlabel('dt')
plt.ylabel('MSE')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
MSE_sigma = torch.load('MSE_sigma_N2000_epsilon0.3_T251.pt') ##(dt, 5method, exp)
sigma_list = torch.load('sigma_list.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/1968095553.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
plt.plot(sigma_list, MSE_sigma[:, 0, :].mean(axis=-1), label = 'NN without control',color='C0')
plt.plot(sigma_list, MSE_sigma[:, 1, :].mean(axis=-1), label = 'NN with control',color='C1')
plt.plot(sigma_list, MSE_sigma[:, 2, :].mean(axis=-1), label = 'Exact solution',color='C2')
plt.plot(sigma_list, MSE_sigma[:, 3, :].mean(axis=-1), label = 'Approximate k',color='C3')
plt.plot(sigma_list, MSE_sigma[:, 4, :].mean(axis=-1), label = 'Open loop',color='C4')
plt.fill_between(sigma_list, MSE_sigma[:, 0, :].min(axis=-1), MSE_sigma[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(sigma_list, MSE_sigma[:, 1, :].min(axis=-1), MSE_sigma[:, 1, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(sigma_list, MSE_sigma[:, 2, :].min(axis=-1), MSE_sigma[:, 2, :].max(axis=-1) , alpha = 0.2,color='C2')
plt.fill_between(sigma_list, MSE_sigma[:, 3, :].min(axis=-1), MSE_sigma[:, 3, :].max(axis=-1) , alpha = 0.2,color='C3')
plt.fill_between(sigma_list, MSE_sigma[:, 4, :].min(axis=-1), MSE_sigma[:, 4, :].max(axis=-1) , alpha = 0.2,color='C4')
plt.xlabel('sigma')
plt.ylabel('MSE')
plt.legend()
# plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
MSE_sigma = torch.load('MSE_sigma_N2000_epsilon0.3_T251_largersigma.pt') ##(dt, 5method, exp)
sigma_list = torch.load('sigma_list.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/3817070465.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
plt.plot(sigma_list, MSE_sigma[:, 0, :].mean(axis=-1), label = 'NN without control',color='C0')
plt.plot(sigma_list, MSE_sigma[:, 1, :].mean(axis=-1), label = 'NN with control',color='C1')
plt.plot(sigma_list, MSE_sigma[:, 2, :].mean(axis=-1), label = 'Exact solution',color='C2')
plt.plot(sigma_list, MSE_sigma[:, 3, :].mean(axis=-1), label = 'Approximate k',color='C3')
plt.plot(sigma_list, MSE_sigma[:, 4, :].mean(axis=-1), label = 'Open loop',color='C4')
plt.fill_between(sigma_list, MSE_sigma[:, 0, :].min(axis=-1), MSE_sigma[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(sigma_list, MSE_sigma[:, 1, :].min(axis=-1), MSE_sigma[:, 1, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(sigma_list, MSE_sigma[:, 2, :].min(axis=-1), MSE_sigma[:, 2, :].max(axis=-1) , alpha = 0.2,color='C2')
plt.fill_between(sigma_list, MSE_sigma[:, 3, :].min(axis=-1), MSE_sigma[:, 3, :].max(axis=-1) , alpha = 0.2,color='C3')
plt.fill_between(sigma_list, MSE_sigma[:, 4, :].min(axis=-1), MSE_sigma[:, 4, :].max(axis=-1) , alpha = 0.2,color='C4')
plt.xlabel('sigma')
plt.ylabel('MSE')
plt.legend()
# plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
MSE_sigma = torch.load('MSE_sigma_N2000_epsilon1_T251_largersigma.pt') ##(dt, 5method, exp)
sigma_list = torch.load('sigma_list.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/2436192747.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
plt.plot(sigma_list, MSE_sigma[:, 0, :].mean(axis=-1), label = 'NN without control',color='C0')
plt.plot(sigma_list, MSE_sigma[:, 1, :].mean(axis=-1), label = 'NN with control',color='C1')
plt.plot(sigma_list, MSE_sigma[:, 2, :].mean(axis=-1), label = 'Exact solution',color='C2')
plt.plot(sigma_list, MSE_sigma[:, 3, :].mean(axis=-1), label = 'Approximate k',color='C3')
plt.plot(sigma_list, MSE_sigma[:, 4, :].mean(axis=-1), label = 'Open loop',color='C4')
plt.fill_between(sigma_list, MSE_sigma[:, 0, :].min(axis=-1), MSE_sigma[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(sigma_list, MSE_sigma[:, 1, :].min(axis=-1), MSE_sigma[:, 1, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(sigma_list, MSE_sigma[:, 2, :].min(axis=-1), MSE_sigma[:, 2, :].max(axis=-1) , alpha = 0.2,color='C2')
plt.fill_between(sigma_list, MSE_sigma[:, 3, :].min(axis=-1), MSE_sigma[:, 3, :].max(axis=-1) , alpha = 0.2,color='C3')
plt.fill_between(sigma_list, MSE_sigma[:, 4, :].min(axis=-1), MSE_sigma[:, 4, :].max(axis=-1) , alpha = 0.2,color='C4')
plt.xlabel('sigma')
plt.ylabel('MSE')
plt.legend()
# plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
MSE_N = torch.load('MSE_N_epsilon0.3_T251_samplelist.pt') ##(sigma, N, 5method, exp)
N_list = torch.load('N_list.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/3156782075.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
plt.plot(N_list, MSE_N[1,:, 0, :].mean(axis=-1), label = 'NN without control',color='C0')
plt.plot(N_list, MSE_N[1,:, 1, :].mean(axis=-1), label = 'NN with control',color='C1')
plt.plot(N_list, MSE_N[1,:, 2, :].mean(axis=-1), label = 'Exact solution',color='C2')
plt.plot(N_list, MSE_N[1,:, 3, :].mean(axis=-1), label = 'Approximate k',color='C3')
plt.plot(N_list, MSE_N[1,:, 4, :].mean(axis=-1), label = 'Open loop',color='C4')
plt.fill_between(N_list, MSE_N[1,:, 0, :].min(axis=-1), MSE_N[1,:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(N_list, MSE_N[1,:, 1, :].min(axis=-1), MSE_N[1,:, 1, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(N_list, MSE_N[1,:, 2, :].min(axis=-1), MSE_N[1,:, 2, :].max(axis=-1) , alpha = 0.2,color='C2')
plt.fill_between(N_list, MSE_N[1,:, 3, :].min(axis=-1), MSE_N[1,:, 3, :].max(axis=-1) , alpha = 0.2,color='C3')
plt.fill_between(N_list, MSE_N[1,:, 4, :].min(axis=-1), MSE_N[1,:, 4, :].max(axis=-1) , alpha = 0.2,color='C4')
plt.xlabel('N')
plt.ylabel('MSE')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
plt.figure()
plt.plot(N_list, MSE_N[0,:, 0, :].mean(axis=-1), label = 'NN without control',color='C0')
plt.plot(N_list, MSE_N[0,:, 1, :].mean(axis=-1), label = 'NN with control',color='C1')
plt.plot(N_list, MSE_N[0,:, 2, :].mean(axis=-1), label = 'Exact solution',color='C2')
plt.plot(N_list, MSE_N[0,:, 3, :].mean(axis=-1), label = 'Approximate k',color='C3')
plt.plot(N_list, MSE_N[0,:, 4, :].mean(axis=-1), label = 'Open loop',color='C4')
plt.fill_between(N_list, MSE_N[0,:, 0, :].min(axis=-1), MSE_N[0,:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(N_list, MSE_N[0,:, 1, :].min(axis=-1), MSE_N[0,:, 1, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(N_list, MSE_N[0,:, 2, :].min(axis=-1), MSE_N[0,:, 2, :].max(axis=-1) , alpha = 0.2,color='C2')
plt.fill_between(N_list, MSE_N[0,:, 3, :].min(axis=-1), MSE_N[0,:, 3, :].max(axis=-1) , alpha = 0.2,color='C3')
plt.fill_between(N_list, MSE_N[0,:, 4, :].min(axis=-1), MSE_N[0,:, 4, :].max(axis=-1) , alpha = 0.2,color='C4')
plt.xlabel('N')
plt.ylabel('MSE')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
MSE_N = torch.load('MSE_N_epsilon0.3_T251_samplelist_new.pt') ##(sigma, N, 5method, exp)
N_list = torch.load('N_list.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/330747660.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
plt.plot(N_list, MSE_N[0,:, 0, :].mean(axis=-1), label = 'NN without control',color='C0')
plt.plot(N_list, MSE_N[0,:, 1, :].mean(axis=-1), label = 'NN with control',color='C1')
plt.plot(N_list, MSE_N[0,:, 2, :].mean(axis=-1), label = 'Exact solution without control',color='C2')
plt.plot(N_list, MSE_N[0,:, 3, :].mean(axis=-1), label = 'Exact solution with control',color='C3')
plt.plot(N_list, MSE_N[0,:, 4, :].mean(axis=-1), label = 'Open loop',color='C4')
plt.fill_between(N_list, MSE_N[0,:, 0, :].min(axis=-1), MSE_N[0,:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(N_list, MSE_N[0,:, 1, :].min(axis=-1), MSE_N[0,:, 1, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(N_list, MSE_N[0,:, 2, :].min(axis=-1), MSE_N[0,:, 2, :].max(axis=-1) , alpha = 0.2,color='C2')
plt.fill_between(N_list, MSE_N[0,:, 3, :].min(axis=-1), MSE_N[0,:, 3, :].max(axis=-1) , alpha = 0.2,color='C3')
plt.fill_between(N_list, MSE_N[0,:, 4, :].min(axis=-1), MSE_N[0,:, 4, :].max(axis=-1) , alpha = 0.2,color='C4')
plt.xlabel('N')
plt.ylabel('MSE')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
plt.figure()
plt.plot(N_list, MSE_N[1,:, 0, :].mean(axis=-1), label = 'NN without control',color='C0')
plt.plot(N_list, MSE_N[1,:, 1, :].mean(axis=-1), label = 'NN with control',color='C1')
plt.plot(N_list, MSE_N[1,:, 2, :].mean(axis=-1), label = 'Exact solution without control',color='C2')
plt.plot(N_list, MSE_N[1,:, 3, :].mean(axis=-1), label = 'Exact solution with control',color='C3')
plt.plot(N_list, MSE_N[1,:, 4, :].mean(axis=-1), label = 'Open loop',color='C4')
plt.fill_between(N_list, MSE_N[1,:, 0, :].min(axis=-1), MSE_N[1,:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(N_list, MSE_N[1,:, 1, :].min(axis=-1), MSE_N[1,:, 1, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(N_list, MSE_N[1,:, 2, :].min(axis=-1), MSE_N[1,:, 2, :].max(axis=-1) , alpha = 0.2,color='C2')
plt.fill_between(N_list, MSE_N[1,:, 3, :].min(axis=-1), MSE_N[1,:, 3, :].max(axis=-1) , alpha = 0.2,color='C3')
plt.fill_between(N_list, MSE_N[1,:, 4, :].min(axis=-1), MSE_N[1,:, 4, :].max(axis=-1) , alpha = 0.2,color='C4')
plt.xlabel('N')
plt.ylabel('MSE')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
MSE_dt = torch.load('MSE_dt_epsilon0.3_N1000_sigma.pt') ##(sigma, N, 5method, exp)
dt_list = torch.load('dt_list.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/3107715848.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
plt.plot(dt_list, MSE_dt[:, 0, :].mean(axis=-1), label = 'NN without control',color='C0')
plt.plot(dt_list, MSE_dt[:, 1, :].mean(axis=-1), label = 'NN with control',color='C1')
plt.plot(dt_list, MSE_dt[:, 2, :].mean(axis=-1), label = 'Exact solution without control',color='C2')
plt.plot(dt_list, MSE_dt[:, 3, :].mean(axis=-1), label = 'Exact solution with control',color='C3')
plt.plot(dt_list, MSE_dt[:, 4, :].mean(axis=-1), label = 'Open loop',color='C4')
plt.fill_between(dt_list, MSE_dt[:, 0, :].min(axis=-1), MSE_dt[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(dt_list, MSE_dt[:, 1, :].min(axis=-1), MSE_dt[:, 1, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(dt_list, MSE_dt[:, 2, :].min(axis=-1), MSE_dt[:, 2, :].max(axis=-1) , alpha = 0.2,color='C2')
plt.fill_between(dt_list, MSE_dt[:, 3, :].min(axis=-1), MSE_dt[:, 3, :].max(axis=-1) , alpha = 0.2,color='C3')
plt.fill_between(dt_list, MSE_dt[:, 4, :].min(axis=-1), MSE_dt[:, 4, :].max(axis=-1) , alpha = 0.2,color='C4')
plt.xlabel('dt')
plt.ylabel('MSE')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
print(MSE_dt[:, 0, :].mean(axis=-1))
print(MSE_dt[:, 1, :].mean(axis=-1))
print(MSE_dt[:, 2, :].mean(axis=-1))
print(MSE_dt[:, 3, :].mean(axis=-1))
print(MSE_dt[:, 4, :].mean(axis=-1))
# Out:
# [0.0058994  0.0058103  0.00680799 0.01117435 0.06412433 1.55930275]
# [0.00500782 0.00453885 0.00703856 0.01512275 0.05096602 0.10043989]
# [0.00036369 0.00070968 0.00183332 0.0036544  0.00921113 0.01785346]
# [0.00036369 0.0007097  0.00183319 0.00365515 0.00922609 0.01810822]
# [0.18293886 0.17771458 0.17990869 0.18296122 0.18117009 0.18331391]

# %%
MSE_sigma = torch.load('MSE_sigma_epsilon0.3_N1000_T251.pt') ##(sigma, N, 5method, exp)
sigma_list = torch.load('sigma_list.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/336579796.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
plt.plot(sigma_list, MSE_sigma[:, 0, :].mean(axis=-1), label = r'Algorithm($u_t=0$)',color='C0', linestyle='--')
plt.plot(sigma_list, MSE_sigma[:, 1, :].mean(axis=-1), label = r'Algorithm($u_t\neq 0$)',color='C0')
plt.plot(sigma_list, MSE_sigma[:, 2, :].mean(axis=-1), label = r'Exact($u_t=0$)',color='C1', linestyle='--')
plt.plot(sigma_list, MSE_sigma[:, 3, :].mean(axis=-1), label = r'Exact($u_t\neq 0$)',color='C1')
plt.plot(sigma_list, MSE_sigma[:, 4, :].mean(axis=-1), label = 'Open-loop',color='black', linestyle='dotted')
plt.fill_between(sigma_list, MSE_sigma[:, 0, :].min(axis=-1), MSE_sigma[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(sigma_list, MSE_sigma[:, 1, :].min(axis=-1), MSE_sigma[:, 1, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(sigma_list, MSE_sigma[:, 2, :].min(axis=-1), MSE_sigma[:, 2, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(sigma_list, MSE_sigma[:, 3, :].min(axis=-1), MSE_sigma[:, 3, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(sigma_list, MSE_sigma[:, 4, :].min(axis=-1), MSE_sigma[:, 4, :].max(axis=-1) , alpha = 0.2,color='black')
plt.xlabel(r'$\sigma$')
plt.ylabel('MSE')
plt.legend()
# plt.xscale('log')
plt.yscale('log')
plt.savefig('MSE_sigma_epsilon03_N1000_T251.pdf')

# %%
print(MSE_sigma[:, 0, :])
print(MSE_sigma[:, 1, :].mean(axis=-1))
print(MSE_sigma[:, 2, :].mean(axis=-1))
print(MSE_sigma[:, 3, :].mean(axis=-1))
print(MSE_sigma[:, 4, :].mean(axis=-1))
# Out:
# [[0.00144801 0.00119204 0.00114773 0.00105513 0.00117588 0.00115185
#   0.00098362 0.00150958 0.00108404 0.00112071]]
# [0.00127086]
# [0.00072032]
# [0.00072032]
# [0.17824196]

# %%
MSE_dt = torch.load('MSE_dt_epsilon0.3_N1000_sigma0.0.pt') ##(sigma, N, 5method, exp)
dt_list = torch.load('dt_list.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/1698305686.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
new_dt_list = [1/0.002, 1/0.004, 1/0.01, 1/0.02, 1/0.05, 1/0.1]

# %%
plt.figure()
# plt.plot(dt_list, MSE_dt[:, 0, :].mean(axis=-1), label = r'NN',color='C0', linestyle='--')
plt.plot(new_dt_list, MSE_dt[:, 1, :].mean(axis=-1), color='C0')
# plt.plot(dt_list, MSE_dt[:, 2, :].mean(axis=-1), label = r'Sol',color='C1', linestyle='--')
plt.plot(new_dt_list, MSE_dt[:, 3, :].mean(axis=-1), color='C1')
plt.plot(new_dt_list, MSE_dt[:, 4, :].mean(axis=-1), color='black', linestyle='dotted')
# plt.fill_between(dt_list, MSE_dt[:, 0, :].min(axis=-1), MSE_dt[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(new_dt_list, MSE_dt[:, 1, :].min(axis=-1), MSE_dt[:, 1, :].max(axis=-1) , alpha = 0.2,color='C0')
# plt.fill_between(dt_list, MSE_dt[:, 2, :].min(axis=-1), MSE_dt[:, 2, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(new_dt_list, MSE_dt[:, 3, :].min(axis=-1), MSE_dt[:, 3, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(new_dt_list, MSE_dt[:, 4, :].min(axis=-1), MSE_dt[:, 4, :].max(axis=-1) , alpha = 0.2,color='black')
plt.xlabel(r'1/$\Delta t$')
plt.ylabel('MSE')
# plt.legend()
plt.xscale('log')
plt.yscale('log')
# plt.show()
plt.savefig('MSE_1divdt_epsilon03_N1000_sigma00.pdf')

# %%
print(MSE_dt[:, 0, :].mean(axis=-1))
print(MSE_dt[:, 1, :].mean(axis=-1))
print(MSE_dt[:, 2, :].mean(axis=-1))
print(MSE_dt[:, 3, :].mean(axis=-1))
print(MSE_dt[:, 4, :].mean(axis=-1))
# Out:
# [0.00605655 0.03594164 0.0208294  0.00840572 0.09081534 0.91963984]
# [0.00461015 0.00974816 0.01248364 0.01700688 0.05177712 0.12647482]
# [0.0003578  0.00073108 0.00182361 0.0035098  0.00922425 0.01804795]
# [0.0003578  0.00073107 0.00182342 0.00351031 0.00923406 0.01823739]
# [0.17842983 0.17743496 0.18158078 0.18084057 0.18226651 0.18007834]

# %%
unorm = torch.load('unorm_sigma_epsilon0.3_N1000_dttensor([0.0040]).pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/2600410955.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
# plt.plot(sigma_list, unorm[:, 0, :].mean(axis=-1), label = r'NN',color='C0', linestyle='--')
plt.plot(sigma_list, unorm[:, 1, :].mean(axis=-1), color='C0')
# plt.plot(sigma_list, unorm[:, 2, :].mean(axis=-1), label = r'Sol',color='C1', linestyle='--')
plt.plot(sigma_list, unorm[:, 3, :].mean(axis=-1), color='C1')
plt.plot(sigma_list, unorm[:, 4, :].mean(axis=-1), color='black', linestyle='dotted')
# plt.fill_between(sigma_list, unorm[:, 0, :].min(axis=-1), unorm[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(sigma_list, unorm[:, 1, :].min(axis=-1), unorm[:, 1, :].max(axis=-1) , alpha = 0.2,color='C0')
# plt.fill_between(sigma_list, unorm[:, 2, :].min(axis=-1), unorm[:, 2, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(sigma_list, unorm[:, 3, :].min(axis=-1), unorm[:, 3, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(sigma_list, unorm[:, 4, :].min(axis=-1), unorm[:, 4, :].max(axis=-1) , alpha = 0.2,color='black')
plt.xlabel(r'$\sigma$')
plt.ylabel(r'$U_{norm}$')
# plt.legend()
# plt.xscale('log')
# plt.yscale('log')
plt.savefig('unorm_sigma_epsilon03_N1000_T251.pdf')

# %%
NN_u = torch.load('NNu_sigma0.0_epsilon0.3_N1000_T251.pt')
Openloop = torch.load('Openloop_sigma0.0_epsilon0.3_N1000_T251.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/3716836834.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
x_0 = [0, 0]
y = [2, 2]

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(Openloop[:,i,0], Openloop[:,i,1], color='C1', alpha=0.5, label='Open loop')
        # plt.plot(NN_u[:,i,0].detach().numpy(), NN_u[:,i,1].detach().numpy(), color='C0', alpha=0.5, label=r'NN+$u_t$')
    else:
        plt.plot(Openloop[:,i,0], Openloop[:,i,1], color='C1', alpha=0.5)
        # plt.plot(NN_u[:,i,0].detach().numpy(), NN_u[:,i,1].detach().numpy(), color='C0', alpha=0.5)
for i in range(50):
    if i == 0:
        # plt.plot(Openloop[:,i,0], Openloop[:,i,1], color='C1', alpha=0.5, label='Open loop')
        plt.plot(NN_u[:,i,0].detach().numpy(), NN_u[:,i,1].detach().numpy(), color='C0', alpha=0.5, label=r'NN+$u_t$')
    else:
        # plt.plot(Openloop[:,i,0], Openloop[:,i,1], color='C1', alpha=0.3)
        plt.plot(NN_u[:,i,0].detach().numpy(), NN_u[:,i,1].detach().numpy(), color='C0', alpha=0.5)
plt.plot(x_0[0], x_0[1], color='r', marker='o', markersize=10, label='start', ls='None')
plt.plot(y[0], y[1], color='black', marker='o', markersize=10, label='traget', ls='None')
plt.xlabel(r'$X_1(t)$')
plt.ylabel(r'$X_2(t)$')
plt.legend()
plt.savefig('NNu_Openloop_sigma00_epsilon03_N1000_T251.pdf')

# %%
((NN_u[-1,:,:].detach() - torch.tensor(y))**2).sum(dim=1).mean()
# Out:
# tensor(0.0010)

# %%
NN_u = torch.load('IP_NNu_sigma0.0_epsilon0.3_N1000_T1251.pt')
Openloop = torch.load('IP_Openloop_sigma0.0_epsilon0.3_N1000_T1251.pt')
NN = torch.load('IP_NN_sigma0.0_epsilon0.3_N1000_T1251.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/2071136773.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(Openloop[:,i,0], Openloop[:,i,1], color='C1', alpha=0.5, label='Open loop')
        # plt.plot(NN_u[:,i,0].detach().numpy(), NN_u[:,i,1].detach().numpy(), color='C0', alpha=0.5, label=r'NN+$u_t$')
    else:
        plt.plot(Openloop[:,i,0], Openloop[:,i,1], color='C1', alpha=0.5)
        # plt.plot(NN_u[:,i,0].detach().numpy(), NN_u[:,i,1].detach().numpy(), color='C0', alpha=0.5)
for i in range(50):
    if i == 0:
        # plt.plot(Openloop[:,i,0], Openloop[:,i,1], color='C1', alpha=0.5, label='Open loop')
        plt.plot(NN_u[:,i-25,0].detach().numpy(), NN_u[:,i-25,1].detach().numpy(), color='C0', alpha=0.5, label=r'NN+$u_t$')
    else:
        # plt.plot(Openloop[:,i,0], Openloop[:,i,1], color='C1', alpha=0.3)
        plt.plot(NN_u[:,i-25,0].detach().numpy(), NN_u[:,i-25,1].detach().numpy(), color='C0', alpha=0.5)
plt.plot(np.pi, 0, color='r', marker='o', markersize=10, label='Bottom', ls='None')
plt.plot(-np.pi, 0, color='r', marker='o', markersize=10, ls='None')
plt.plot(0, 0, color='black', marker='o', markersize=10, label='Top',ls='None')
plt.xlabel(r'$X_1(t)$')
plt.ylabel(r'$X_2(t)$')
plt.legend()
plt.savefig('IP_NNu_Openloop_sigma00_epsilon03_N1000_T251.pdf')

# %%
print(((NN[-1,:,:].detach() - torch.tensor([[0.0,0.0]]))**2).sum(dim=1).mean())
# Out:
# tensor(0.0014)

# %%
print(((NN_u[-1,:,:].detach() - torch.tensor([[0.0,0.0]]))**2).sum(dim=1).mean())
# Out:
# tensor(0.0019)

# %%
X_b = torch.load('X_b.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/244102735.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   X_b = torch.load('X_b.pt')

# %%
plt.figure()
plt.plot(X_b[:,1,0], X_b[:,1,1])
plt.plot(Openloop[:,1,0], Openloop[:,1,1])
plt.xlabel(r'$X_1(t)$')
plt.ylabel(r'$X_2(t)$')
# plt.savefig('X_b.pdf')
# Out:
# Text(0, 0.5, '$X_2(t)$')

# %%
MSE_IP_sigma_exp12 = torch.load('IP_MSE_sigma_epsilon0.3_N1000_T1251exp12.pt') ##(sigma, N, 5method, exp)
MSE_IP_sigma_exp34 = torch.load('IP_MSE_sigma_epsilon0.3_N1000_T1251exp34.pt') ##(sigma, N, 5method, exp)
MSE_IP_sigma_exp5 = torch.load('IP_MSE_sigma_epsilon0.3_N1000_T1251exp5.pt') ##(sigma, N, 5method, exp)
# MSE_IP_sigma = torch.cat([MSE_IP_sigma_exp12, MSE_IP_sigma_exp34, MSE_IP_sigma_exp5], dim=-1)
MSE_IP_sigma = np.concatenate([MSE_IP_sigma_exp12, MSE_IP_sigma_exp34, MSE_IP_sigma_exp5], axis=-1)
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/3654692771.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
plt.plot(sigma_list, MSE_IP_sigma[:, 0, :].mean(axis=-1), label = r'NN',color='C0', linestyle='--')
plt.plot(sigma_list, MSE_IP_sigma[:, 1, :].mean(axis=-1), label = r'NN+$u_t$',color='C0')
# plt.plot(sigma_list, MSE_sigma[:, 2, :].mean(axis=-1), label = r'Sol',color='C1', linestyle='--')
# plt.plot(sigma_list, MSE_sigma[:, 3, :].mean(axis=-1), label = r'Sol+$u_t$',color='C1')
plt.plot(sigma_list, MSE_IP_sigma[:, 4, :].mean(axis=-1), label = 'Open loop',color='black', linestyle='dotted')
plt.fill_between(sigma_list, MSE_IP_sigma[:, 0, :].min(axis=-1), MSE_IP_sigma[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(sigma_list, MSE_IP_sigma[:, 1, :].min(axis=-1), MSE_IP_sigma[:, 1, :].max(axis=-1) , alpha = 0.2,color='C0')
# plt.fill_between(sigma_list, MSE_sigma[:, 2, :].min(axis=-1), MSE_sigma[:, 2, :].max(axis=-1) , alpha = 0.2,color='C1')
# plt.fill_between(sigma_list, MSE_sigma[:, 3, :].min(axis=-1), MSE_sigma[:, 3, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(sigma_list, MSE_IP_sigma[:, 4, :].min(axis=-1), MSE_IP_sigma[:, 4, :].max(axis=-1) , alpha = 0.2,color='black')
plt.xlabel(r'$\sigma$')
plt.ylabel('MSE')
plt.legend()
# plt.xscale('log')
plt.yscale('log')
plt.savefig('IP_MSE_sigma_epsilon03_N1000_T1251.pdf')

# %%
IP_unorm12 = torch.load('IP_unorm_sigma_epsilon0.3_N1000_T1251exp12.pt')
IP_unorm34 = torch.load('IP_unorm_sigma_epsilon0.3_N1000_T1251exp34.pt')
IP_unorm5 = torch.load('IP_unorm_sigma_epsilon0.3_N1000_T1251exp5.pt')
IP_unorm = np.concatenate([IP_unorm12, IP_unorm34, IP_unorm5], axis=-1)
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/697514303.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
plt.plot(sigma_list, IP_unorm[:, 0, :].mean(axis=-1), label = r'NN',color='C0', linestyle='--')
plt.plot(sigma_list, IP_unorm[:, 1, :].mean(axis=-1), label = r'NN+$u_t$',color='C0')
plt.plot(sigma_list, IP_unorm[:, 4, :].mean(axis=-1), label = 'Open loop',color='black', linestyle='dotted')
plt.fill_between(sigma_list, IP_unorm[:, 0, :].min(axis=-1), IP_unorm[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(sigma_list, IP_unorm[:, 1, :].min(axis=-1), IP_unorm[:, 1, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(sigma_list, IP_unorm[:, 4, :].min(axis=-1), IP_unorm[:, 4, :].max(axis=-1) , alpha = 0.2,color='black')
plt.xlabel(r'$\sigma$')
plt.ylabel(r'$U_{norm}$')
plt.legend()
plt.savefig('IP_unorm_sigma_epsilon03_N1000_T1251.pdf')

# %%
dt_list = [0.002, 0.004, 0.01, 0.02, 0.05, 0.1]
MSE_IP_dt123 = torch.load('IP_MSE_dt_epsilon0.3_N1000_sigma0.0exp123.pt') ##(sigma, N, 5method, exp)
MSE_IP_dt45 = torch.load('IP_MSE_dt_epsilon0.3_N1000_sigma0.0exp45.pt') ##(sigma, N, 5method, exp)
MSE_IP_dt = np.concatenate([MSE_IP_dt123, MSE_IP_dt45], axis=-1)
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/3492050057.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
plt.figure()
plt.plot(dt_list, MSE_IP_dt[:, 0, :].mean(axis=-1), label = r'NN',color='C0', linestyle='--')
plt.plot(dt_list, MSE_IP_dt[:, 1, :].mean(axis=-1), label = r'NN+$u_t$',color='C0')
# plt.plot(dt_list, MSE_IP_dt[:, 2, :].mean(axis=-1), label = r'Sol',color='C1', linestyle='--')
# plt.plot(dt_list, MSE_IP_dt[:, 3, :].mean(axis=-1), label = r'Sol+$u_t$',color='C1')
plt.plot(dt_list, MSE_IP_dt[:, 4, :].mean(axis=-1), label = 'Open loop',color='black', linestyle='dotted')
plt.fill_between(dt_list, MSE_IP_dt[:, 0, :].min(axis=-1), MSE_IP_dt[:, 0, :].max(axis=-1) , alpha = 0.2,color='C0')
plt.fill_between(dt_list, MSE_IP_dt[:, 1, :].min(axis=-1), MSE_IP_dt[:, 1, :].max(axis=-1) , alpha = 0.2,color='C0')
# plt.fill_between(dt_list, MSE_IP_dt[:, 2, :].min(axis=-1), MSE_IP_dt[:, 2, :].max(axis=-1) , alpha = 0.2,color='C1') 
# plt.fill_between(dt_list, MSE_IP_dt[:, 3, :].min(axis=-1), MSE_IP_dt[:, 3, :].max(axis=-1) , alpha = 0.2,color='C1')
plt.fill_between(dt_list, MSE_IP_dt[:, 4, :].min(axis=-1), MSE_IP_dt[:, 4, :].max(axis=-1) , alpha = 0.2,color='black')
plt.xlabel(r'$\Delta t$')
plt.ylabel('MSE')
plt.legend()
plt.xscale('log')
plt.yscale('log')
plt.savefig('IP_MSE_dt_epsilon03_N1000_sigma00.pdf')

# %%
X_traj = torch.load('NNu_sigma0.0_epsilon0.3_N1000_T2514fig1.pt')
Z_traj = torch.load('X_backward_u_sigma0.0_epsilon0.3_N1000_T2514fig1.pt')
u_traj = torch.load('u_sigma0.0_epsilon0.3_N1000_T2514fig1.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/3421620532.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
Z_traj = Z_traj.detach().numpy()
X_traj = X_traj.detach().numpy()
u_traj = u_traj.detach().numpy()
# Z_traj = Z_traj[::-1,:,:]

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 251, 1)*0.004, Z_traj[:,i,0], label=r'$\tilde Z_t(1)$', color='C1')
    else:
        plt.plot(np.arange(0, 251, 1)*0.004, Z_traj[:,i,0], color='C1', alpha=0.5)
    if i == 0:
        plt.plot(np.arange(0, 251, 1)*0.004, X_traj[:,i,0], label=r'$ X_t(1)$', color='C0')
    else:
        plt.plot(np.arange(0, 251, 1)*0.004, X_traj[:,i,0], color='C0', alpha=0.5)
    
plt.plot(np.arange(0, 251, 1)*0.004, np.ones(251)*2.0 , color='black', linestyle='--', label=r'$x_f(1)$')
plt.xlabel(r'$t$')
plt.ylabel(r'$X_t(1)$')
plt.legend()
plt.savefig('X_Z1_traj_new.pdf')

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 251, 1)*0.004, Z_traj[:,i,1], label=r'$\tilde Z_t(2)$', color='C1')
    else:
        plt.plot(np.arange(0, 251, 1)*0.004, Z_traj[:,i,1], color='C1', alpha=0.5)
    if i == 0:
        plt.plot(np.arange(0, 251, 1)*0.004, X_traj[:,i,1], label=r'$X_t(2)$', color='C0')
    else:
        plt.plot(np.arange(0, 251, 1)*0.004, X_traj[:,i,1], color='C0', alpha=0.5)
    
plt.plot(np.arange(0, 251, 1)*0.004, np.ones(251)*2.0 , color='black', linestyle='--', label=r'$x_f(2)$')
plt.xlabel(r'$t$')
plt.ylabel(r'$X_t(2)$')
plt.legend()
plt.savefig('X_Z2_traj_new.pdf')

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 251, 1)*0.004, u_traj[:,i, 0], label=r'$U_t(1)$', color='C2')
    else:
        plt.plot(np.arange(0, 251, 1)*0.004, u_traj[:,i,0], color='C2', alpha=0.5)
    if i == 0:
        plt.plot(np.arange(0, 251, 1)*0.004, u_traj[:,i,1], label=r'$U_t(2)$', color='C3')
    else:
        plt.plot(np.arange(0, 251, 1)*0.004, u_traj[:,i,1], color='C3', alpha=0.5)
plt.xlabel(r'$t$')
plt.ylabel(r'$U_t$')
plt.legend()
plt.savefig('u_traj_new.pdf')

# %%
((X_traj[-1,:,:] - np.array([2.0,2.0]))**2).sum(axis=1).mean()
# Out:
# 0.0010857505812245875

# %%
IP_X_traj = torch.load('IP_traj_sigma0.0_epsilon0.3_N1000_T1251.pt')
IP_Z_traj = torch.load('IP_Z_traj_sigma0.0_epsilon0.3_N1000_T1251.pt')
IP_u_traj = torch.load('IP_u1_sigma0.0_epsilon0.3_N1000_T1251.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/1372190008.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
IP_Z_traj = IP_Z_traj.detach().numpy()
IP_X_traj = IP_X_traj.detach().numpy()
IP_u_traj = IP_u_traj.detach().numpy()
# IP_Z_traj = IP_Z_traj[::-1,:,:]

# %%
((IP_X_traj[-1,:,:])**2).sum(axis=1).mean()
# Out:
# 0.0038493283

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj[:,i-25,0], label=r'$\tilde Z_t(1)$', color='C1')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj[:,i-25,0], color='C1', alpha=0.5)
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj[:,i-25,0], label=r'$X_t(1)$', color='C0')
        
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj[:,i-25,0], color='C0', alpha=0.5)
plt.plot(np.arange(0, 1251, 1)*0.004, np.zeros(1251) , color='black', linestyle='--', label=r'$x_f(1)$')
plt.xlabel(r'$t$')
plt.ylabel(r'$X_t(1)$')
plt.legend()
plt.savefig('IP_X_Z1_traj_new.pdf')

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj[:,i-25,1], label=r'$\tilde Z_t(2)$', color='C1')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj[:,i-25,1], color='C1', alpha=0.5)
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj[:,i-25,1], label=r'$X_t(2)$', color='C0')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj[:,i-25,1], color='C0', alpha=0.5)
plt.plot(np.arange(0, 1251, 1)*0.004, np.zeros(1251) , color='black', linestyle='--', label=r'$x_f(2)$')
plt.xlabel(r'$t$')
plt.ylabel(r'$X_t(2)$')
plt.legend()
plt.savefig('IP_X_Z2_traj_new.pdf')

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_u_traj[:,i, 0], label=r'$U_t$', color='C2')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_u_traj[:,i,0], color='C2', alpha=0.5)
plt.xlabel(r'$t$')
plt.ylabel(r'$U_t$')
plt.legend()
plt.savefig('IP_u_traj_new.pdf')

# %%
print((IP_X_traj[-1,:,:]**2).sum(axis=1).mean())
# Out:
# 0.029644776

# %%
IP_X_traj_3d = torch.load('3dIP_traj_sigma0.05_epsilon0.3_N1000_T1251.pt')
IP_Z_traj_3d = torch.load('3dIP_Z_traj_sigma0.05_epsilon0.3_N1000_T1251.pt')
# IP_u_traj = torch.load('IP_u1_sigma0.0_epsilon1_N1000_T1251.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/1675847464.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
IP_Z_traj_3d = IP_Z_traj_3d.detach().numpy()
IP_X_traj_3d = IP_X_traj_3d.detach().numpy()

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d[:,i-25,0], label=r'$\tilde Z_t(1)$', color='C1')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d[:,i-25,0], color='C1', alpha=0.5)
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d[:,i-25,0], label=r'$X_t(1)$', color='C0')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d[:,i-25,0], color='C0', alpha=0.5)
plt.plot(np.arange(0, 1251, 1)*0.004, np.zeros(1251) , color='black', linestyle='--', label=r'$x_f(1)$')
plt.xlabel(r'$t$')
plt.ylabel(r'$X_t(1)$')
plt.legend()
plt.savefig('3dIP_X_Z1_traj_new.pdf')

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d[:,i-25,1], label=r'$\tilde Z_t(2)$', color='C1')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d[:,i-25,1], color='C1', alpha=0.5)
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d[:,i-25,1], label=r'$X_t(2)$', color='C0')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d[:,i-25,1], color='C0', alpha=0.5)
plt.plot(np.arange(0, 1251, 1)*0.004, np.zeros(1251) , color='black', linestyle='--', label=r'$x_f(2)$')
plt.xlabel(r'$t$')
plt.ylabel(r'$X_t(2)$')
plt.legend()
plt.savefig('3dIP_X_Z2_traj_new.pdf')

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d[:,i-25,2], label=r'$\tilde Z_t(3)$', color='C1')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d[:,i-25,2], color='C1', alpha=0.5)
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d[:,i-25,2], label=r'$X_t(3)$', color='C0')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d[:,i-25,2], color='C0', alpha=0.5)
plt.plot(np.arange(0, 1251, 1)*0.004, np.zeros(1251) , color='black', linestyle='--', label=r'$x_f(3)$')
plt.xlabel(r'$t$')
plt.ylabel(r'$X_t(3)$')
plt.legend()
plt.savefig('3dIP_X_Z3_traj_new.pdf')

# %%
IP_X_traj_3d_con = torch.load('3dIP_traj_sigma0.3_epsilon0.3_N1500_T1251.pt')
IP_Z_traj_3d_con = torch.load('3dIP_Z_traj_sigma0.3_epsilon0.3_N1500_T1251.pt')
# Out:
# /var/folders/pd/hp6m3j2j5v9bd6w64h7wl3rm0000gn/T/ipykernel_86525/344304079.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
IP_Z_traj_3d_con = IP_Z_traj_3d_con.detach().numpy()
IP_X_traj_3d_con = IP_X_traj_3d_con.detach().numpy()

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d_con[:,i-25,0], label=r'$Z_t$', color='C1')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d_con[:,i-25,0], color='C1', alpha=0.5)
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d_con[:,i-25,0], label=r'$X_t$', color='C0')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d_con[:,i-25,0], color='C0', alpha=0.5)
plt.plot(np.arange(0, 1251, 1)*0.004, np.zeros(1251) , color='black', linestyle='--', label=r'$x_f$')
plt.xlabel(r'$t$')
plt.ylabel(r'$X_1(t)$')
plt.legend()

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d_con[:,i-25,1], label=r'$Z_t$', color='C1')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d_con[:,i-25,1], color='C1', alpha=0.5)
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d_con[:,i-25,1], label=r'$X_t$', color='C0')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d_con[:,i-25,1], color='C0', alpha=0.5)
plt.plot(np.arange(0, 1251, 1)*0.004, np.zeros(1251) , color='black', linestyle='--', label=r'$x_f$')
plt.xlabel(r'$t$')
plt.ylabel(r'$X_2(t)$')
plt.legend()

# %%
plt.figure()
for i in range(50):
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d_con[:,i-25,2], label=r'$Z_t$', color='C1')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_Z_traj_3d_con[:,i-25,2], color='C1', alpha=0.5)
    if i == 0:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d_con[:,i-25,2], label=r'$X_t$', color='C0')
    else:
        plt.plot(np.arange(0, 1251, 1)*0.004, IP_X_traj_3d_con[:,i-25,2], color='C0', alpha=0.5)

# %%
test = torch.ones(3,2)*0.1
test[0,0] = 0.5
test[1,1] = 0.2
(((test**2).sum(dim=1))).mean()
# Out:
# tensor(0.1100)
